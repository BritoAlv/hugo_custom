# %% [markdown]
# # Exploratory Analysis
#
# This notebook is a link target. Notebooks are converted to static pages
# without executing them.

# %%
x = 41
print(f"answer = {x + 1}")
# Out:
# answer = 42
